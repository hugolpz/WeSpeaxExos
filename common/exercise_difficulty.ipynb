# %%
# import relevant libraries
import re

import numpy as np
import pandas as pd
import scipy.stats as stat
from wordfreq import (
    tokenize, 
    zipf_frequency
)

# %%
from exercise_difficulty import Difficulty

# %%
en_exo_df = pd.read_excel("../en/English_Exercises.xlsx")

word_exo_objs = ["Learning vocabulary"]
sent_exo_objs = ["Useful Sentences", "Grammar"]

difficulty_class = Difficulty(exo_df = en_exo_df, language = "en", word_exo_objs = word_exo_objs, sent_exo_objs = sent_exo_objs)

complete_exo_en_df = difficulty_class.find_all_scores()
# Out:
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   word_exo_df["Difficulty"] = list(map(self.find_difficulty_level, quantile_ranks))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_exo_df["Length_sentence"] = sent_exo_df["Full_sentence"].apply(lambda text: self.sentence_length(str(text)))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_exo_df["Length_traget_word"] = sent_exo_df["Right_answer"].apply(lambda text: len(str(text)))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_exo_df["Length_longest_word"] = sent_exo_df["Full_sentence"].apply(lambda text: self.find_wLengthMax(str(text)))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_exo_df["Frequency_rarest_word"] = sent_exo_df["Right_answer"].apply(lambda text: self.find_wSRarest(str(text)))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_exo_df["Score_sentence"] = sent_exo_df["Full_sentence"].apply(lambda text: self.find_SScore(str(text)))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_exo_df["Difficulty"] = list(map(self.find_difficulty_level, quantile_ranks))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:213: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return word_exo_df.append(sent_exo_df,ignore_index = True)

# %%
complete_exo_en_df.head()
# Out:
#    Exo_type_id Exo_type        Exo_objective  Exo_focus  Exo_id Source_format  \
# 0           14      MCQ  Learning vocabulary  Spellings       1          text
# 1           14      MCQ  Learning vocabulary  Spellings       2          text
# 2           14      MCQ  Learning vocabulary  Spellings       3          text
# 3           14      MCQ  Learning vocabulary  Spellings       4          text
# 4           14      MCQ  Learning vocabulary  Spellings       5          text
#
#   Target_format  Source_sentence_id  Source_word_id Source_lang  ...  \
# 0          text                 NaN             8.0      French  ...
# 1          text                 NaN            13.0      French  ...
# 2          text                 NaN            44.0      French  ...
# 3          text                 NaN            61.0      French  ...
# 4          text                 NaN            80.0      French  ...
#
#           Dist_2      Dist_3 Explanation Difficulty Remediation  \
# 0   Difffference  Differance         NaN         B2         NaN
# 1  Cleanlinessss  Clenliness         NaN         C1         NaN
# 2       Narrrrow      Nerrow         NaN         B1         NaN
# 3    Excellllent   Excellant         NaN         B2         NaN
# 4        Plesant   Pleaasant         NaN         B2         NaN
#
#   Length_sentence Length_traget_word Length_longest_word  \
# 0             NaN                NaN                 NaN
# 1             NaN                NaN                 NaN
# 2             NaN                NaN                 NaN
# 3             NaN                NaN                 NaN
# 4             NaN                NaN                 NaN
#
#    Frequency_rarest_word Score_sentence
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2                    NaN            NaN
# 3                    NaN            NaN
# 4                    NaN            NaN
#
# [5 rows x 26 columns]

# %%
complete_exo_en_df.to_csv("../en/English_Exercises_with_Difficulty.csv", index = False)

# %%
hi_exo_df = pd.read_excel("../hi/Hindi_Exercises.xlsx")

word_exo_objs = ["Learning vocabulary"]
sent_exo_objs = ["Useful Sentences", "Grammar"]

difficulty_class = Difficulty(exo_df = hi_exo_df, language = "hi", word_exo_objs = word_exo_objs, sent_exo_objs = sent_exo_objs)

complete_exo_hi_df = difficulty_class.find_all_scores()
# Out:
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   word_exo_df["Difficulty"] = list(map(self.find_difficulty_level, quantile_ranks))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_exo_df["Length_sentence"] = sent_exo_df["Full_sentence"].apply(lambda text: self.sentence_length(str(text)))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_exo_df["Length_traget_word"] = sent_exo_df["Right_answer"].apply(lambda text: len(str(text)))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_exo_df["Length_longest_word"] = sent_exo_df["Full_sentence"].apply(lambda text: self.find_wLengthMax(str(text)))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_exo_df["Frequency_rarest_word"] = sent_exo_df["Right_answer"].apply(lambda text: self.find_wSRarest(str(text)))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_exo_df["Score_sentence"] = sent_exo_df["Full_sentence"].apply(lambda text: self.find_SScore(str(text)))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_exo_df["Difficulty"] = list(map(self.find_difficulty_level, quantile_ranks))
# d:\Puntu\WeSpeaxExos\common\exercise_difficulty.py:213: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return word_exo_df.append(sent_exo_df,ignore_index = True)

# %%
complete_exo_hi_df.head()
# Out:
#    Exo_type_id    Exo_type        Exo_objective Exo_focus  Exo_id  \
# 0           10  Flashcards  Learning vocabulary       NaN       1
# 1           10  Flashcards  Learning vocabulary       NaN       2
# 2           10  Flashcards  Learning vocabulary       NaN       3
# 3           10  Flashcards  Learning vocabulary       NaN       4
# 4           10  Flashcards  Learning vocabulary       NaN       5
#
#   Source_format Target_format  Source_sentence_id  Source_word_id Source_lang  \
# 0          text          text                 NaN             2.0      French
# 1          text          text                 NaN             3.0      French
# 2          text          text                 NaN             4.0      French
# 3          text          text                 NaN             5.0      French
# 4          text          text                 NaN             6.0      French
#
#    ... Dist_2 Dist_3 Explanation Difficulty Remediation Length_sentence  \
# 0  ...    NaN    NaN         NaN         A1         NaN             NaN
# 1  ...    NaN    NaN         NaN         C1         NaN             NaN
# 2  ...    NaN    NaN         NaN         C1         NaN             NaN
# 3  ...    NaN    NaN         NaN         A2         NaN             NaN
# 4  ...    NaN    NaN         NaN         C1         NaN             NaN
#
#   Length_traget_word Length_longest_word  Frequency_rarest_word Score_sentence
# 0                NaN                 NaN                    NaN            NaN
# 1                NaN                 NaN                    NaN            NaN
# 2                NaN                 NaN                    NaN            NaN
# 3                NaN                 NaN                    NaN            NaN
# 4                NaN                 NaN                    NaN            NaN
#
# [5 rows x 26 columns]

# %%
complete_exo_hi_df.to_csv("../hi/Hindi_Exercises_with_Difficulty.csv", index = False)
